# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422 (from 1)
# Receiving objects: 100% (422/422), 34.08 MiB | 30.59 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
ls
# Out:
# OIDv4_ToolKit/  sample_data/

# %%
cd OIDv4_ToolKit/
# Out:
# /content/OIDv4_ToolKit

# %%
ls
# Out:
# classes.txt  images/  LICENSE  main.py  modules/  README.md  requirements.txt

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 101.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 41.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.21.2
#     Uninstalling docutils-0.21.2:
#       Successfully uninstalled docutils-0.21.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.1.3 requires docutils<0.22,>=0.20, but you have docutils 0.16 which is incompatible.
# ...

# %%
# !python main.py downloader --classes Bird Butterfly --type_csv train --limit 500 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Bird', 'Butterfly'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 47627 KB/s, 0 seconds passed
# ...

# %% [markdown]
# ### Conjunto de imagens de Validação

# %%
# !python main.py downloader --classes Bird Butterfly --type_csv test --limit 100 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Bird', 'Butterfly'] together.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 49 MB, 22245 KB/s, 2 seconds passed
# ...

# %%
# !cat classes.txt
# Out:
# Apple
# Orange
# Light switch

# %%
# !echo -e 'Bird\nButterfly' > classes.txt

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import argparse
import fileinput

# %%
# função que transforma as coordenadas XMin, YMin, XMax, YMax no formato normalizado pro YOLO/darknet
def convert(nome_file, coords):
    os.chdir("..")
    imagem = cv2.imread(nome_file + ".jpg")
    coords[2] -= coords[0]         # diferença largura (x_fim - x_inicio)
    coords[3] -= coords[1]         # diferença altura (y_fim - y_inicio)
    x_dif = int(coords[2] / 2)     # converte diferença_largura pra int
    y_dif = int(coords[3] / 2)     # converte diferença_altura pra int
    coords[0] = coords[0] + x_dif  # x_inicio + diferença largura
    coords[1] = coords[1] + y_dif  # y_inicio + diferença altura
    largura = int(imagem.shape[1]) # = largura da imagem
    altura = int(imagem.shape[0])  # = altura da imagem
    coords[0] /= largura           # x = (int((<x fim> - <x inicio>) / 2) + <x inicio>) / <largura_imagem>
    coords[1] /= altura            # (int((<y fim> - <y inicio>) / 2) + <y inicio)) / <altura_imagem>
    coords[2] /= largura           # largura = (<x fim> - <x inicio>) / <largura_imagem>
    coords[3] /= altura            # altura (<y fim> - <y inicio>) / <altura_imagem>
    os.chdir("Label")
    return coords

# %%
ROOT_DIR = os.getcwd()

# cria um dicionario para mapear os nomes das classes em numeros para o YOLO
classes = {}
with open("classes.txt", "r") as myFile:
    for num, line in enumerate(myFile, 0):
        line = line.rstrip("\n")
        classes[line] = num
    myFile.close()
# vai ate o diretorio do dataset
os.chdir(os.path.join("OID", "Dataset"))
DIRS = os.listdir(os.getcwd())

# %%
# percorre as pastas train, validation e test
for DIR in DIRS:
    if os.path.isdir(DIR):

        # se contem ponto no nome da pasta entao pula pra proxima (pra por ex ignorar o .ipynb_checkpoints)
        if "." in DIR:
            continue

        os.chdir(DIR)
        print("Subdiretorio atual:", DIR)

        class_dirs = os.listdir(os.getcwd())
        # percorre todas as classes para alterar os annotations
        for class_dir in class_dirs:
            if os.path.isdir(class_dir):

                if "." in class_dir:
                    continue

                os.chdir(class_dir)
                print("Convertendo os annotations para a classe: ", class_dir)

                # vai até a pasta Label que é onde os annotations estão
                os.chdir("Label")

                for filename in tqdm(os.listdir(os.getcwd())):
                    nome_file = str.split(filename, ".")[0]
                    if filename.endswith(".txt"):
                        annotations = []
                        with open(filename) as f:
                            # agora altera os valores para cada linha dentro do txt
                            for line in f:
                                for class_type in classes:
                                    line = line.replace(class_type, str(classes.get(class_type)))
                                labels = line.split()
                                coords = np.asarray([float(labels[1]), float(labels[2]), float(labels[3]), float(labels[4])])
                                coords = convert(nome_file, coords)
                                labels[1], labels[2], labels[3], labels[4] = coords[0], coords[1], coords[2], coords[3]
                                newline = str(labels[0]) + " " + str(labels[1]) + " " + str(labels[2]) + " " + str(labels[3]) + " " + str(labels[4])
                                line = line.replace(line, newline) # atualiza os valores da linha
                                annotations.append(line) # adiciona ao final da linha
                            f.close()
                        os.chdir("..")
                        # agora precisamos voltar um diretorio acima pois iremos salvar os novos txt na mesma pasta onde estão as imagens
                        with open(filename, "w") as outfile:
                            for line in annotations:
                                outfile.write(line)
                                outfile.write("\n")
                            outfile.close()
                        os.chdir("Label")
                os.chdir("..")
                os.chdir("..")
        os.chdir("..")
# Out:
# Subdiretorio atual: test
# Convertendo os annotations para a classe:  Bird_Butterfly
# 100%|██████████| 200/200 [00:01<00:00, 125.67it/s]
# Subdiretorio atual: train
# Convertendo os annotations para a classe:  Bird_Butterfly
# 100%|██████████| 1000/1000 [00:20<00:00, 49.57it/s]

# %%
# %cd /content/OIDv4_ToolKit/OID/Dataset/train/
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/train

# %%
# !zip -r ../../../obj.zip obj -x obj/Label/*
# Out:
#   adding: obj/ (stored 0%)
#   adding: obj/681061a922794a48.jpg (deflated 0%)
#   adding: obj/d9e34da473482296.txt (deflated 31%)
#   adding: obj/6b4d68d027ad43c7.jpg (deflated 0%)
#   adding: obj/7f551e58df4c7398.jpg (deflated 0%)
#   adding: obj/07a2826b71068721.jpg (deflated 1%)
#   adding: obj/e805b409838e8524.jpg (deflated 0%)
#   adding: obj/f4574a30a0383212.jpg (deflated 1%)
#   adding: obj/d761ad5c06b5f9f8.txt (deflated 54%)
#   adding: obj/552e6a6b084147ec.txt (deflated 25%)
#   adding: obj/626841f58e1f9958.jpg (deflated 0%)
#   adding: obj/92de8096d557649b.txt (deflated 31%)
#   adding: obj/38ef97ff619b2f64.txt (deflated 23%)
#   adding: obj/fd0c0cdb65fd8f28.txt (deflated 31%)
#   adding: obj/d2c1c2967d55c0bb.jpg (deflated 0%)
#   adding: obj/b29f8be6f0a562c6.jpg (deflated 0%)
#   adding: obj/d68adeec5f61824a.jpg (deflated 0%)
#   adding: obj/d84e84ea5ca62486.txt (deflated 22%)
#   adding: obj/02970ca9b484af9d.txt (deflated 14%)
# ...

# %%
ls
# Out:
# obj/

# %%
cd ..
# Out:
# /content/OIDv4_ToolKit/OID/Dataset

# %%
cd test/
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/test

# %%
ls
# Out:
# valid/

# %%
# !zip -r ../../../valid.zip valid -x valid/Label/*
# Out:
#   adding: valid/ (stored 0%)
#   adding: valid/e6428aa2793efcab.jpg (deflated 0%)
#   adding: valid/3e2367cb7a78fc3b.jpg (deflated 1%)
#   adding: valid/953188006d25b6aa.txt (deflated 29%)
#   adding: valid/7d0bc6911b95b8c7.jpg (deflated 1%)
#   adding: valid/709bb69695f093b1.txt (deflated 31%)
#   adding: valid/98ff54513bba2950.txt (deflated 8%)
#   adding: valid/6b61aa038cc8da54.jpg (deflated 0%)
#   adding: valid/48e6282864e599fc.jpg (deflated 0%)
#   adding: valid/8166e9cade345143.txt (deflated 20%)
#   adding: valid/899d2f973daf6378.jpg (deflated 0%)
#   adding: valid/1875e60f7a735345.txt (deflated 12%)
#   adding: valid/4227260bb78c999a.jpg (deflated 0%)
#   adding: valid/ce45e2166588b4c3.txt (deflated 23%)
#   adding: valid/76e5d3587b8dd826.jpg (deflated 0%)
#   adding: valid/204e836352f960f4.jpg (deflated 1%)
#   adding: valid/0a4d46a98790f3a5.jpg (deflated 0%)
#   adding: valid/a4dfea72fc3140f9.txt (deflated 12%)
#   adding: valid/e60d148d428e96cd.jpg (deflated 4%)
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# valid/

# %%
cd ../../../
# Out:
# /content/OIDv4_ToolKit

# %%
# !cp ./obj.zip /content/gdrive/My\ Drive/Treinamento_YOLO

# %%
# !cp ./valid.zip /content/gdrive/My\ Drive/Treinamento_YOLO

# %%
cd ..
# Out:
# /content

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15873, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15873 (delta 3), reused 0 (delta 0), pack-reused 15863 (from 3)
# Receiving objects: 100% (15873/15873), 14.47 MiB | 22.32 MiB/s, done.
# Resolving deltas: 100% (10686/10686), done.

# %%
cd darknet/
# Out:
# /content/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:866:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   866 |         for (int i = 0; i < v.size(); ++i) {
#       |                         ~~^~~~~~~~~~
# ...

# %%
# !cp cfg/yolov4.cfg /content/gdrive/My\ Drive/Treinamento_YOLO/yolov4_custom.cfg

# %%
# !touch obj.names
# !touch obj.data

# %%
# !cp obj.names /content/gdrive/My\ Drive/Treinamento_YOLO/obj.names
# !cp obj.data /content/gdrive/My\ Drive/Treinamento_YOLO/obj.data

# %%
cd ..
# Out:
# /content

# %%
cd OIDv4_ToolKit/
# Out:
# /content/OIDv4_ToolKit

# %%
# !unzip obj.zip -d ./data
# Out:
# Archive:  obj.zip
# replace ./data/obj/681061a922794a48.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
#   inflating: ./data/obj/681061a922794a48.jpg
# replace ./data/obj/d9e34da473482296.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ./data/obj/d9e34da473482296.txt
#   inflating: ./data/obj/6b4d68d027ad43c7.jpg
#   inflating: ./data/obj/7f551e58df4c7398.jpg
#   inflating: ./data/obj/07a2826b71068721.jpg
#   inflating: ./data/obj/e805b409838e8524.jpg
#   inflating: ./data/obj/f4574a30a0383212.jpg
#   inflating: ./data/obj/d761ad5c06b5f9f8.txt
#   inflating: ./data/obj/552e6a6b084147ec.txt
#   inflating: ./data/obj/626841f58e1f9958.jpg
#   inflating: ./data/obj/92de8096d557649b.txt
#   inflating: ./data/obj/38ef97ff619b2f64.txt
#   inflating: ./data/obj/fd0c0cdb65fd8f28.txt
#   inflating: ./data/obj/d2c1c2967d55c0bb.jpg
#   inflating: ./data/obj/b29f8be6f0a562c6.jpg
#   inflating: ./data/obj/d68adeec5f61824a.jpg
#   inflating: ./data/obj/d84e84ea5ca62486.txt
# ...

# %%
# !unzip valid.zip -d ./data
# Out:
# Archive:  valid.zip
# replace ./data/valid/e6428aa2793efcab.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ./data/valid/e6428aa2793efcab.jpg
#   inflating: ./data/valid/3e2367cb7a78fc3b.jpg
#   inflating: ./data/valid/953188006d25b6aa.txt
#   inflating: ./data/valid/7d0bc6911b95b8c7.jpg
#   inflating: ./data/valid/709bb69695f093b1.txt
#   inflating: ./data/valid/98ff54513bba2950.txt
#   inflating: ./data/valid/6b61aa038cc8da54.jpg
#   inflating: ./data/valid/48e6282864e599fc.jpg
#   inflating: ./data/valid/8166e9cade345143.txt
#   inflating: ./data/valid/899d2f973daf6378.jpg
#   inflating: ./data/valid/1875e60f7a735345.txt
#   inflating: ./data/valid/4227260bb78c999a.jpg
#   inflating: ./data/valid/ce45e2166588b4c3.txt
#   inflating: ./data/valid/76e5d3587b8dd826.jpg
#   inflating: ./data/valid/204e836352f960f4.jpg
#   inflating: ./data/valid/0a4d46a98790f3a5.jpg
#   inflating: ./data/valid/a4dfea72fc3140f9.txt
#   inflating: ./data/valid/e60d148d428e96cd.jpg
# ...

# %%
# o que o codigo abaixo faz: adiciona o nome e caminho de todos as fotos (.jpg) em um txt
imagens = []
os.chdir(os.path.join("data", "obj"))
for filename in os.listdir(os.getcwd()):
    if filename.endswith(".jpg"):
        imagens.append("data/obj/" + filename)
os.chdir("..")

with open("train.txt", "w") as outfile:
    for img in imagens:
        outfile.write(img)
        outfile.write("\n")
    outfile.close()
os.chdir("..")

# %%
# o que o codigo abaixo faz: adiciona o nome e caminho de todos as fotos (.jpg) em um txt
imagens = []
os.chdir(os.path.join("data", "valid"))
for filename in os.listdir(os.getcwd()):
    if filename.endswith(".jpg"):
        imagens.append("data/valid/" + filename)
os.chdir("..")

with open("test.txt", "w") as outfile:
    for img in imagens:
        outfile.write(img)
        outfile.write("\n")
    outfile.close()
os.chdir("..")

# %%
# %cd /content/OIDv4_ToolKit/data/
# Out:
# /content/OIDv4_ToolKit/data

# %%
# !cp train.txt /content/gdrive/My\ Drive/Treinamento_YOLO/train.txt

# %%
# !cp test.txt /content/gdrive/My\ Drive/Treinamento_YOLO/test.txt
